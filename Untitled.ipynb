# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re
import numpy as np

# %%
url = 'https://www.howardcountymd.gov/police/newsroom'
soup = BeautifulSoup(requests.get(url).text, "html.parser")

# %%
def get_parced_data(raw):
    if raw.find_all("div", {"id": "daily-crime-bulletin"}):
        if raw.find_all("div", {"class": "paragraph--accordion__title"}):
            if raw.find_all("div", {"class": "field__item"}):
                return raw.find_all("div", {"class": "field__item"})

# %%
parced_data = get_parced_data(soup)
crimes = [] 

for child in parced_data:
    if(child.find('h2')):
        crimes.append(child)

# %%
# crimes[0]

# %%
crimes_by_date = pd.DataFrame(columns=['publish_date','category','raw_crimes'])
for x in crimes:
    publish_date = x.find("h2").text.split(',',1)[1]
    raw_crimes = x.find_all("p")
    for c in raw_crimes:
        if c.find("u"):
            for cat in c.find_all("u"):
                category = 'cat.text'
                crimes_by_date.loc[len(crimes_by_date.index)] = [publish_date, category, raw_crimes]

# %%
# regex 
cat_regex = re.compile(r'<p><strong><u>(?P<cat>[a-zA-Z \/-]*)<\/u><br\/>')
city_regex = re.compile(r'(?P<city>[a-zA-z ]*),\s\d{5}')
zip_regex = re.compile(r'[a-zA-z ]*,\s(?P<zip>\d{5}):')
date_regex = re.compile(r'(?P<date>\w+\.?\s\d+-?\d*)')
time_regex = re.compile(r'\s(?P<time>\d{1,2}:\d{1,2}\s*[a.mp]*)')
street_regex = re.compile(r':\s?<\/strong>(?P<street>.*),\s?(March|Feb.|February)?')
notes_time_regex = re.compile(r':\d{1,2}\s*[a.mp]*<br\/>\s(.*)<')
notes_date_regex = re.compile(r'\w+\.?\s\d+-?\d*.*,\s(.*)<')

# %%
by_crime_df = pd.DataFrame(columns=['publish_date', 'category', 'city', 'zip_code', 'street', 'crime_date', 'crime_time', 'add_notes'])

def by_crime(x):
    for c in x['raw_crimes']:
        cat = np.NaN
        street = np.NaN
        crime_date = np.NaN
        crime_time = np.NaN
        add_notes = np.NaN
        
        if cat_regex.findall(str(c)):
            cat = cat_regex.findall(str(c))[0]
        if city_regex.findall(str(c)):
            city = city_regex.findall(str(c))[0]
        if zip_regex.findall(str(c)):
            zip_code = zip_regex.findall(str(c))[0]
        # Fetch Street
        if street_regex.findall(str(c)):
            street = street_regex.findall(str(c))[0][0]
        if 'March' in street:
            street = street.split('March')[0]
        if 'Feb.' in street:
            street = street.split('Feb.')[0]
        if 'Feburary' in street:
            street = street.split('Feburary')[0]
        if date_regex.findall(str(c)):
            crime_date = date_regex.findall(str(c))[0]
        if time_regex.findall(str(c)):
            crime_time = time_regex.findall(str(c))[0]
        if notes_time_regex.findall(str(c)):
            add_notes = notes_time_regex.findall(str(c))[0]
#         if add_notes.isnull():
#             add_notes = notes_date_regex.findall(str(c))[0]
        by_crime_df.loc[len(by_crime_df.index)] = [x['publish_date'], cat, city, zip_code, street, crime_date, crime_time, add_notes]

# %%
crimes_by_date.apply(by_crime,axis = 1)
by_crime_df['category'].fillna(method='ffill',inplace = True)
by_crime_df.drop_duplicates(inplace = True)
by_crime_df.reset_index(drop=True)
# Out:
#           publish_date                             category           city  \
# 0    March 17-18, 2022                              Robbery       Columbia
# 1    March 17-18, 2022                 Residential burglary         Laurel
# 2    March 17-18, 2022  Theft from vehicle/vehicle break-in       Columbia
# 3    March 17-18, 2022  Theft from vehicle/vehicle break-in       Columbia
# 4    March 17-18, 2022                        Vehicle theft       Elkridge
# 5    March 17-18, 2022                        Vehicle theft       Columbia
# 6    March 17-18, 2022                        Vehicle theft       Columbia
# 7    March 17-18, 2022                        Vehicle theft       Columbia
# 8       March 16, 2022                  Commercial burglary         Savage
# 9       March 16, 2022  Theft from vehicle/vehicle break-in       Columbia
# 10      March 16, 2022                        Vehicle theft       Columbia
# 11      March 15, 2022                  Commercial burglary       Columbia
# 12      March 15, 2022  Theft from vehicle/vehicle break-in       Columbia
# 13      March 15, 2022                        Vehicle theft       Columbia
# 14      March 14, 2022                     Weapon violation       Elkridge
# 15      March 14, 2022  Theft from vehicle/vehicle break-in       Columbia
# 16      March 14, 2022  Theft from vehicle/vehicle break-in       Elkridge
# 17      March 11, 2022                              Robbery  Ellicott City
# 18      March 10, 2022  Theft from vehicle/vehicle break-in       Elkridge
# 19      March 10, 2022  Theft from vehicle/vehicle break-in       Columbia
# 20      March 10, 2022  Theft from vehicle/vehicle break-in       Columbia
# 21      March 10, 2022                        Vehicle theft         Laurel
# 22      March 10, 2022                        Vehicle theft  Ellicott City
# 23      March 10, 2022                        Vehicle theft       Columbia
# 24       March 8, 2022                     Weapon violation         Laurel
# 25       March 8, 2022                              Robbery       Columbia
# 26       March 8, 2022  Theft from vehicle/vehicle break-in       Elkridge
# 27       March 8, 2022  Theft from vehicle/vehicle break-in  Ellicott City
# 28       March 8, 2022  Theft from vehicle/vehicle break-in       Columbia
# 29       March 8, 2022  Theft from vehicle/vehicle break-in       Columbia
# 30       March 8, 2022  Theft from vehicle/vehicle break-in         Laurel
# 31       March 8, 2022                        Vehicle theft       Elkridge
# 32       March 7, 2022                Home invasion/robbery  Ellicott City
# 33       March 7, 2022                              Robbery       Elkridge
# 34       March 7, 2022                 Residential burglary  Ellicott City
# 35       March 7, 2022  Theft from vehicle/vehicle break-in  Ellicott City
# 36       March 7, 2022  Theft from vehicle/vehicle break-in       Columbia
# 37       March 7, 2022  Theft from vehicle/vehicle break-in       Columbia
# 38       March 7, 2022  Theft from vehicle/vehicle break-in       Columbia
# 39       March 7, 2022                        Vehicle theft       Elkridge
# 40       March 7, 2022                        Vehicle theft       Columbia
# 41       March 4, 2022                        Vehicle theft        Hanover
# 42       March 4, 2022                        Vehicle theft       Columbia
# 43       March 3, 2022  Theft from vehicle/vehicle break-in         Laurel
# 36    21046                9600 block of Broken Land Parkway,       March 4
# 37    21044                     5300 block of Hesperus Drive,     March 5-6
# 38    21045                  6400 block of Dobbin Center Way,       March 7
# 39    21075                         7000 block of Barnett Lane    March 3-4
# 40    21044                      6100 block of Satinwood Drive      March 4
# 41    21076                    7300 block of Coca Cola Drive,       March 3
# 42    21045                      7000 block of Deepage Drive,       March 3
# 43    20723               9000 block of Old Scaggsville Road,     March 1-2
# 44    21046                     6300 block of Woodside Court,     March 1-2
# 45    20723                        9600 block of Coronet Court    March 1-2
# 46    21043                      4900 block of Montgomery Road     Feb. 24-
# 47    21046                        9300 block of Gerwig Lane,       March 1
# 48    21043               6000 block of University Boulevard,       March 1
# 49    21044                       11200 block of Slalom Lane,     March 1-2
# 50    21075                 7000 block of New Colony Boulevard      March 1
# 51    20723                 9000 block of Old Scaggsville Road      March 2
# 52    20794                8200 block of Patuxent Range Road,       Feb. 25
# 53    21075               7800 block of Washington Boulevard,       Feb. 25
# 54    21046                        9200 block of Berger Road,    Feb. 26-28
# 55    21045                           5900 block of Cedar Fern   Feb. 25-26
#
#     crime_time                                          add_notes
# 0    7:39 a.m.  A store employee reported that when he confron...
# 1    2:20 p.m.  Unknown suspect(s) attempted to break into a d...
# 2          NaN                                                NaN
# 3          NaN                                                NaN
# 4    9:16 p.m.          2001 green Toyota Avalon, tags MD/2DD2814
# 5          NaN                                                NaN
# 6          NaN                                                NaN
# 7          NaN                                                NaN
# 8          NaN                                                NaN
# 9          NaN                                                NaN
# 10         NaN                                                NaN
# 11         NaN                                                NaN
# 12         NaN                                                NaN
# 13         NaN                                                NaN
# 14   3:18 a.m.  Police responded for a report of a vehicle in ...
# 15         NaN                                                NaN
# 16         NaN                                                NaN
# 17   3:10 p.m.  A juvenile male victim reported that he had be...
# 18   1:30 p.m.                                                NaN
# 19         NaN                                                NaN
# 20         NaN                                                NaN
# 21         NaN                                                NaN
# 22         NaN                                                NaN
# 23         NaN                                                NaN
# 24         NaN                                                NaN
# 25         NaN                                                NaN
# 26         NaN                                                NaN
# 27  12:10 a.m.                                                NaN
# 28         NaN                                                NaN
# 29         NaN                                                NaN
# 30         NaN                                                NaN
# 31         NaN                                                NaN
# 32         NaN                                                NaN
# 33   6:20 a.m.  An adult male victim reported that he was appr...
# 34         NaN                                                NaN
# 35         NaN                                                NaN
# 36         NaN                                                NaN
# 37         NaN                                                NaN
# 38         NaN                                                NaN
# 39         NaN                                                NaN
# 40   9:05 a.m.            2011 black Toyota RAV4, tags MD/9CE6826
# 41         NaN                                                NaN
# 42         NaN                                                NaN
# 43         NaN                                                NaN
# 44         NaN                                                NaN
# 45         NaN                                                NaN
# 46         NaN                                                NaN
# 47         NaN                                                NaN
# 48         NaN                                                NaN
# 49         NaN                                                NaN
# 50         NaN                                                NaN
# 51         NaN                                                NaN
# 52         NaN                                                NaN
# 53   2:47 p.m.                                                NaN
# 54         NaN                                                NaN
# 55         NaN                                                NaN

# %%
by_crime_df['add_notes'].isnull().sum()
# Out:
# 49

# %%
by_crime_df.to_csv('data/howard-daily-crime-bulletin.csv')
